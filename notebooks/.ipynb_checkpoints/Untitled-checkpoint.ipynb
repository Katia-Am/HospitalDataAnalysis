# %%
import pandas as pd

# Load the data
df = pd.read_csv("../data/Patients.csv")

# Display the first rows
print("✅ Data loaded successfully!\n")
df.head()
# Out:
# ✅ Data loaded successfully!
#    PatientID  Age Sex  BloodPressure  Cholesterol         Diagnosis
# 0          1   45   F            120          200            Normal
# 1          2   34   M            135          240      Hypertension
# 2          3   67   F            160          180  High Cholesterol
# 3          4   23   M            110          190            Normal
# 4          5   56   F            145          220      Hypertension

# %%
# Display dataset info
print("🩺 Dataset Information:")
print(df.info())

# Basic statistics for numerical columns
print("\n📊 Descriptive Statistics:")
print(df.describe())

# Count patients by diagnosis
print("\n📋 Diagnosis counts:")
print(df["Diagnosis"].value_counts())
# Out:
# 🩺 Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PatientID      5 non-null      int64
#  1   Age            5 non-null      int64
#  2   Sex            5 non-null      object
#  3   BloodPressure  5 non-null      int64
#  4   Cholesterol    5 non-null      int64
#  5   Diagnosis      5 non-null      object
# dtypes: int64(4), object(2)
# memory usage: 372.0+ bytes
# None
#
# 📊 Descriptive Statistics:
#        PatientID        Age  BloodPressure  Cholesterol
# count   5.000000   5.000000       5.000000     5.000000
# mean    3.000000  45.000000     134.000000   206.000000
# std     1.581139  17.392527      19.811613    24.083189
# min     1.000000  23.000000     110.000000   180.000000
# 25%     2.000000  34.000000     120.000000   190.000000
# 50%     3.000000  45.000000     135.000000   200.000000
# ...

# %%
# Run bas ic desc r Opt i ve s tat i s I i cs us ing:

df.describe()
df['Sex'].value counts() df['Diagnosis'].value counts()
# Out:
#   Cell In[3], line 4
#     df['Sex'].value counts() df['Diagnosis'].value counts()
#                     ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# Load the data
df = pd.read_csv("../data/Patients.csv")
df.head()
# Out:
#    PatientID  Age Sex  BloodPressure  Cholesterol         Diagnosis
# 0          1   45   F            120          200            Normal
# 1          2   34   M            135          240      Hypertension
# 2          3   67   F            160          180  High Cholesterol
# 3          4   23   M            110          190            Normal
# 4          5   56   F            145          220      Hypertension

# %%
# Basic stats (mean, min, max, etc.)
df.describe()
# Out:
#        PatientID        Age  BloodPressure  Cholesterol
# count   5.000000   5.000000       5.000000     5.000000
# mean    3.000000  45.000000     134.000000   206.000000
# std     1.581139  17.392527      19.811613    24.083189
# min     1.000000  23.000000     110.000000   180.000000
# 25%     2.000000  34.000000     120.000000   190.000000
# 50%     3.000000  45.000000     135.000000   200.000000
# 75%     4.000000  56.000000     145.000000   220.000000
# max     5.000000  67.000000     160.000000   240.000000

# %%
# Count of each Sex category
df['Sex'].value_counts()

# Count of each Diagnosis category
df['Diagnosis'].value_counts()
# Out:
# Diagnosis
# Normal              2
# Hypertension        2
# High Cholesterol    1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.plot(df["Age"], df["Cholesterol"], marker="o")
plt.xlabel("Age")
plt.ylabel("Cholesterol")
plt.title("Cholesterol vs Age")
plt.show()

# %%
import pandas as pd

# Load your CSV file
data = pd.read_csv('../data/patients.csv')

# Display the first few rows
data.head()
# Out:
#    PatientID  Age Sex  BloodPressure  Cholesterol         Diagnosis
# 0          1   45   F            120          200            Normal
# 1          2   34   M            135          240      Hypertension
# 2          3   67   F            160          180  High Cholesterol
# 3          4   23   M            110          190            Normal
# 4          5   56   F            145          220      Hypertension

# %%
import pandas as pd

# Load your dataset
data = pd.read_csv('../data/patients.csv')

# Display the first few rows
data.head()
# Out:
#    PatientID  Age Sex  BloodPressure  Cholesterol         Diagnosis
# 0          1   45   F            120          200            Normal
# 1          2   34   M            135          240      Hypertension
# 2          3   67   F            160          180  High Cholesterol
# 3          4   23   M            110          190            Normal
# 4          5   56   F            145          220      Hypertension

# %%
# Show basic info
print("Basic Information:")
print(df.info())

# Check for missing values
print("\n Missing values:")
print(df.isnull().sum())

# Check for duplicates
print("\n Duplicates:")
print(df.duplicated().sum())

# Display the first few rows again for review
df.head()
# Out:
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PatientID      5 non-null      int64
#  1   Age            5 non-null      int64
#  2   Sex            5 non-null      object
#  3   BloodPressure  5 non-null      int64
#  4   Cholesterol    5 non-null      int64
#  5   Diagnosis      5 non-null      object
# dtypes: int64(4), object(2)
# memory usage: 372.0+ bytes
# None
#
#  Missing values:
# PatientID        0
# Age              0
# Sex              0
# BloodPressure    0
# Cholesterol      0
# Diagnosis        0
# dtype: int64
#
#  Duplicates:
# 0
#    PatientID  Age Sex  BloodPressure  Cholesterol         Diagnosis
# 0          1   45   F            120          200            Normal
# 1          2   34   M            135          240      Hypertension
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Age distribution
plt.figure(figsize=(6,4))
sns.histplot(df['Age'], bins=8, kde=True)
plt.title("Age Distribution of Patients")
plt.show()

# Blood Pressure vs Cholesterol
plt.figure(figsize=(6,4))
sns.scatterplot(x='BloodPressure', y='Cholesterol', hue='Diagnosis', data=df)
plt.title("Blood Pressure vs Cholesterol by Diagnosis")
plt.show()

# Count by Diagnosis
plt.figure(figsize=(6,4))
sns.countplot(x='Diagnosis', data=df)
plt.title("Number of Patients by Diagnosis")
plt.show()
# Out:
# ----------------------------------------------------------------
# ModuleNotFoundError            Traceback (most recent call last)
# Cell In[12], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import seaborn as sns
#       4 # Age distribution
#       5 plt.figure(figsize=(6,4))
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# !pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Age distribution
plt.figure(figsize=(6,4))
sns.histplot(df['Age'], bins=8, kde=True)
plt.title("Age Distribution of Patients")
plt.show()

# Blood Pressure vs Cholesterol
plt.figure(figsize=(6,4))
sns.scatterplot(x='BloodPressure', y='Cholesterol', hue='Diagnosis', data=df)
plt.title("Blood Pressure vs Cholesterol by Diagnosis")
plt.show()

# Count by Diagnosis
plt.figure(figsize=(6,4))
sns.countplot(x='Diagnosis', data=df)
plt.title("Number of Patients by Diagnosis")
plt.show()

# %%
# Age distribution
plt.figure(figsize=(6,4))
sns.histplot(data['Age'], bins=5, kde=True, color='skyblue')
plt.title('Age Distribution of Patients')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# Sex count
plt.figure(figsize=(5,4))
sns.countplot(x='Sex', hue='Sex', data=data, palette='Set2', legend=False)

plt.title('Number of Male and Female Patients')
plt.show()

# Blood Pressure vs Cholesterol (scatter plot)
plt.figure(figsize=(6,4))
sns.scatterplot(x='BloodPressure', y='Cholesterol', hue='Diagnosis', data=data, s=100)
plt.title('Blood Pressure vs Cholesterol by Diagnosis')
plt.show()

# --- Summary Statistics ---
print("🩺 Summary Statistics:\n")
print(data.describe())

# --- Count diagnoses ---
print("\n📋 Diagnosis counts:\n")
print(data['Diagnosis'].value_counts())

# --- Average values per diagnosis ---
print("\n📊 Average values per Diagnosis:\n")
print(data.groupby('Diagnosis')[['Age', 'BloodPressure', 'Cholesterol']].mean())

# --- Detect patients with high risk (example rule) ---
high_risk = data[(data['BloodPressure'] > 140) | (data['Cholesterol'] > 220)]
print("\n🚨 High-Risk Patients:\n")
print(high_risk[['PatientID', 'Age', 'Sex', 'BloodPressure', 'Cholesterol', 'Diagnosis']])
# Out:
# 🩺 Summary Statistics:
#
#        PatientID        Age  BloodPressure  Cholesterol
# count   5.000000   5.000000       5.000000     5.000000
# mean    3.000000  45.000000     134.000000   206.000000
# std     1.581139  17.392527      19.811613    24.083189
# min     1.000000  23.000000     110.000000   180.000000
# 25%     2.000000  34.000000     120.000000   190.000000
# 50%     3.000000  45.000000     135.000000   200.000000
# 75%     4.000000  56.000000     145.000000   220.000000
# max     5.000000  67.000000     160.000000   240.000000
#
# 📋 Diagnosis counts:
#
# Diagnosis
# Normal              2
# Hypertension        2
# High Cholesterol    1
# Name: count, dtype: int64
#
# 📊 Average values per Diagnosis:
#
#                    Age  BloodPressure  Cholesterol
# Diagnosis
# High Cholesterol  67.0          160.0        180.0
# Hypertension      45.0          140.0        230.0
# Normal            34.0          115.0        195.0
#
# 🚨 High-Risk Patients:
#
# ...

# %% [markdown]
# # 🏥 Hospital Data Analysis — Summary Report
#
# ### 🔍 Overview
# This analysis explored a sample dataset of hospital patients, including their age, gender, blood pressure, cholesterol levels, and diagnosis.
#
# ### 📈 Key Insights
# - **Most common diagnoses:** Hypertension and Normal.
# - **Average blood pressure:** Patients with Hypertension tend to have higher values.
# - **Cholesterol levels:** Slightly elevated among patients diagnosed with High Cholesterol.
# - **High-risk group:** Patients with BloodPressure > 140 or Cholesterol > 220 require special attention.
#
# ### 💡 Conclusion
# This study provides a clear view of patient health trends. Such analysis can help medical staff identify at-risk patients early and personalize their care.
#
# ### 🧰 Tools Used
# - Python 🐍
# - Pandas for data manipulation
# - Seaborn and Matplotlib for visualization
# - Jupyter Notebook for analysis
